# %% [markdown]
# # MNE Groups Data Discovery Challenge - MUR team

# %% [markdown]
# ### Libraries

# %%
import os
import re
import random
import time
import PyPDF2
import requests
import pandas as pd
import yaml
import tempfile
from bs4 import BeautifulSoup
from googlesearch import search
from urllib.parse import urlparse

# %% [markdown]
# ### Configuration

# %%
def load_config(config_file='config.yaml'):
    """
    Loads configuration parameters from a YAML file.

    Parameters:
        config_file (str): The path to the YAML configuration file.

    Returns:
        dict: A dictionary containing the loaded configuration parameters.
    """
    with open(config_file, 'r') as f:
        return yaml.safe_load(f)

# %%
config = load_config()

# --- Global Parameters from Config ---
DATA_PATH = config['data_path']
INPUT_FILENAME = config['input_filename']
OUTPUT_FILENAME = config['output_filename']
KEYWORDS_REPORT = config['keywords_report']
KEYWORDS_FINANCIAL = config['keywords_financial']
KEYWORDS_DISCOVERY = config['keywords_discovery']
VALID_YEARS = [str(year) for year in config['valid_years']]
PAUSE_TIME_MIN = config['pause_time_min']
PAUSE_TIME_MAX = config['pause_time_max']
SEARCH_TIMEOUT = config['search_timeout']
LONG_PAUSE_GROUPS_INTERVAL = config['long_pause_groups_interval']
LONG_PAUSE_TIME = config['long_pause_time']

# %% [markdown]
# ### Functions

# %%
def is_pdf_url(url: str) -> bool:
    """
    Checks if a given URL points to a PDF file.

    Parameters:
        url (str): The URL to check.

    Returns:
        bool: True if the URL ends with '.pdf' (case-insensitive), False otherwise.
    """
    return url.lower().endswith(".pdf")

# %%
def extract_year(text: str, valid_years: list) -> str or None:
    """
    Searches for the first valid year from a list within a given text.

    Parameters:
        text (str): The text content to search within.
        valid_years (list): A list of year strings to look for.

    Returns:
        str or None: The first year found as a string, or None if no valid year is found.
    """
    if text is None:
        return None
    for year in valid_years:
        if str(year) in text:
            return year
    return None

# %%
def extract_year_from_pdf_url(url: str, valid_years: list, group_id: str or int, timeout: int = SEARCH_TIMEOUT) -> str or None:
    """
    Downloads a PDF from the given URL, extracts text from the first page,
    looks for a matching year, and then deletes the temporary file.

    Parameters:
        url (str): The URL of the PDF to download.
        valid_years (list): A list of year strings to search for.
        group_id (str or int): An identifier used to generate a unique temporary filename.
        timeout (int): Timeout in seconds for the HTTP request.

    Returns:
        str or None: The year found in the PDF as a string, or None if no year is found or an error occurs.
    """
    if not url:
        return None

    tmp_filename = os.path.join(tempfile.gettempdir(), f"temp_pdf_{group_id}.pdf")

    try:
        headers = {
            "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) "
                          "AppleWebKit/537.36 (KHTML, like Gecko) "
                          "Chrome/124.0.0.0 Safari/537.36"
        }
        response = requests.get(url, headers=headers, timeout=timeout)
        response.raise_for_status()  # Raise HTTPError for bad responses (4xx or 5xx)

        with open(tmp_filename, "wb") as f:
            f.write(response.content)

        with open(tmp_filename, "rb") as f:
            reader = PyPDF2.PdfReader(f)
            if reader.is_encrypted:
                return None
            if len(reader.pages) > 0:
                text = reader.pages[0].extract_text() or ""
                text = text.lower()
                for year in valid_years:
                    if str(year) in text:
                        return year
                    
    except Exception as e:
        print(f"An unexpected error occurred while processing PDF from {url}: {e}")
    finally:
        if os.path.exists(tmp_filename):
            try:
                os.remove(tmp_filename)
            except Exception as cleanup_error:
                print(f"Warning: could not delete temporary file {tmp_filename}: {cleanup_error}")
    return None

# %%
def get_domain(url: str) -> str:
    """
    Extracts the domain name from a URL.

    Parameters:
        url (str): The input URL.

    Returns:
        str: The domain name (netloc), or an empty string if the URL is invalid.
    """
    try:
        return urlparse(url).netloc
    except:
        return ""

# %%
def check_isin(isin_code: str) -> bool:
    """
    Verifies if a given string is a valid ISIN code, including the check digit calculation.

    Parameters:
        isin_code (str): The ISIN code to validate.

    Returns:
        bool: True if the ISIN code is valid, False otherwise.
    """
    if not isinstance(isin_code, str) or len(isin_code) != 12:
        return False

    isin_code_upper = isin_code.upper()
    if not isin_code_upper[:2].isalpha() or not isin_code_upper[2:].isalnum():
        return False

    converted_digits = []
    for char in isin_code_upper:
        if '0' <= char <= '9':
            converted_digits.append(int(char))
        elif 'A' <= char <= 'Z':
            # Convert letters to numbers (A=10, B=11, ..., Z=35) and then split into digits
            converted_digits.extend(divmod(ord(char) - ord('A') + 10, 10))
        else:
            return False 

    total_sum = 0
    # Luhn algorithm: process from right to left
    for i in range(len(converted_digits) - 1, -1, -1):
        digit = converted_digits[i]
        if (len(converted_digits) - 1 - i) % 2 == 1:
            doubled_digit = digit * 2
            if doubled_digit > 9:
                total_sum += (doubled_digit % 10) + (doubled_digit // 10)
            else:
                total_sum += doubled_digit
        else:
            total_sum += digit
    return total_sum % 10 == 0

# %%
def search_isin(name: str, max_results: int = 10, timeout: int = SEARCH_TIMEOUT) -> str or None:
    """
    Searches for ISIN codes related to a given group name, validates them,
    and returns the first valid one found.

    Parameters:
        name (str): The name of the group to search for.
        max_results (int): The maximum number of search results to check.
        timeout (int): Timeout in seconds for the HTTP request.

    Returns:
        str or None: The first valid ISIN code found, or None if no valid ISIN is found.
    """
    query = f"{name} " + " OR ".join(["isin", "stock"])
    pause_time = random.uniform(PAUSE_TIME_MIN, PAUSE_TIME_MAX)
    time.sleep(pause_time)

    try:
        search_results = list(search(query, num_results=max_results))

        for url in search_results:
            try:
                headers = {
                    "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) "
                                  "AppleWebKit/537.36 (KHTML, like Gecko) "
                                  "Chrome/124.0.0.0 Safari/537.36"
                }
                response = requests.get(url, headers=headers, timeout=timeout)
                response.raise_for_status()
                soup = BeautifulSoup(response.text, "html.parser")
                text = soup.get_text(separator=' ')

                processed_text = re.sub(r'[^a-z0-9\s]', ' ', text.lower())
                isin_pattern = r'\b([a-z]{2}[a-z0-9]{10})\b'
                match = re.search(isin_pattern, processed_text)

                if match and check_isin(match.group(1)):
                    found_isin = match.group(1).upper()
                    return found_isin

            except requests.exceptions.RequestException as e:
                print(f"Error getting URL {url} during ISIN search: {e}")
                continue
            except Exception as e:
                print(f"Error processing URL {url} during ISIN search: {e}")
                continue
        return None

    except Exception as e:
        print(f"Error during Google search for ISIN '{name}': {e}")
        print("Waiting before retrying Google search...")
        time.sleep(LONG_PAUSE_TIME)
        return None

# %%
def page_mentions_keywords(url: str, keywords: list, valid_years: list, timeout: int = SEARCH_TIMEOUT) -> tuple:
    """
    Fetches the page at the given URL and calculates a semantic score
    based on the presence of given keywords in the HTML content.
    Also attempts to extract a reference year from the text.

    Parameters:
        url (str): The URL of the web page.
        keywords (list): A list of keywords or lists of synonyms.
                         If an element is a list, it counts as 1 if at least one synonym is found.
        valid_years (list): A list of acceptable year strings to look for.
        timeout (int): Timeout in seconds for the HTTP request.

    Returns:
        tuple: A tuple containing:
               - score (int): The calculated semantic score.
               - refyear (str or None): The extracted reference year as a string, or None.
    """
    try:
        headers = {"User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) "
                                 "AppleWebKit/537.36 (KHTML, like Gecko) "
                                 "Chrome/124.0.0.0 Safari/537.36"}
        response = requests.get(url, headers=headers, timeout=timeout)
        response.raise_for_status()
        soup = BeautifulSoup(response.text, "html.parser")
        text = soup.get_text(separator=' ').lower()
    except Exception as e:
        return 0, None

    score = 0
    for kw_group in keywords:
        if isinstance(kw_group, list):
            if any(k.lower() in text for k in kw_group):
                score += 1
        else:
            if kw_group.lower() in text:
                score += 1

    refyear = extract_year(text, valid_years)
    return score, refyear

# %%
def search_annual_report_url(name: str, max_results: int = 10) -> str or None:
    """
    Searches Google for an annual report URL for a group, prioritizing PDF files.

    Parameters:
        name (str): The group name.
        max_results (int): The maximum number of Google results to retrieve.

    Returns:
        str or None: The URL of the preferred annual report (PDF if available, otherwise the first result),
                     or None if no relevant URL is found.
    """
    query = f"{name} " + " ".join(KEYWORDS_REPORT)
    pause_time = random.uniform(PAUSE_TIME_MIN, PAUSE_TIME_MAX)
    time.sleep(pause_time)

    try:
        urls = list(search(query, lang="en", num_results=max_results))
        if not urls:
            return None
        preferred = next((u for u in urls if is_pdf_url(u)), urls[0])
        return preferred
    except Exception as e:
        print(f"Error during Google search for annual report '{name}': {e}")
        print("Waiting before retrying Google search...")
        time.sleep(LONG_PAUSE_TIME)
        return None

# %%
def search_other_info_urls(name: str, keywords: list, valid_years: list, max_results: int = 20, max_unique: int = 5, isin_code: str = None) -> list:
    """
    Searches Google for financial information URLs related to a group.

    For each valid URL, the function:
    - Ensures domain uniqueness to avoid multiple links from the same site.
    - Excludes PDF files from the search results.
    - Calculates a semantic score based on keyword presence.
    - Extracts a reference year from the HTML content.

    Parameters:
        name (str): The group name.
        keywords (list): A list of keywords or keyword groups for semantic scoring.
        valid_years (list): A list of valid reference years to search for.
        max_results (int): The total number of Google search results to retrieve.
        max_unique (int): The maximum number of unique domain URLs to return, sorted by score.
        isin_code (str, optional): An ISIN code to include in the search query for better relevance.

    Returns:
        list of tuples: A list where each tuple contains (URL (str), SCORE (int), REFYEAR (str or None)).
                        The list is sorted by SCORE in descending order.
    """
    query = f"{name} " + " OR ".join(KEYWORDS_FINANCIAL)
    if isin_code:
        query = query + " OR " + f"{isin_code}"

    seen_domains = set()
    urls_info = []
    pause_time = random.uniform(PAUSE_TIME_MIN, PAUSE_TIME_MAX)
    time.sleep(pause_time)

    try:
        results = list(search(query, lang="en", num_results=max_results))

        for url in results:
            domain = get_domain(url)
            if (domain in seen_domains) or is_pdf_url(url):
                continue
            seen_domains.add(domain)

            score, refyear = page_mentions_keywords(url, keywords, valid_years)
            if refyear:
                urls_info.append((url, score, refyear))

        # Sort by descending score and keep the top N unique results
        urls_info = sorted(urls_info, key=lambda x: x[1], reverse=True)[:max_unique]

        return urls_info
    except Exception as e:
        print(f"Error during Google search for other info '{name}': {e}")
        print("Waiting before retrying Google search...")
        time.sleep(LONG_PAUSE_TIME)
        return []

# %%
def run_discovery():
    """
    Main function to run the discovery process.
    It reads group data, performs searches for ISIN codes, annual reports,
    and other financial information, and then saves the enriched data to a CSV file.
    """
    input_file_path = os.path.join("..", DATA_PATH, INPUT_FILENAME)
    output_file_path = os.path.join("..", DATA_PATH, OUTPUT_FILENAME)

    if not os.path.exists(os.path.join("..", DATA_PATH)):
        os.makedirs(os.path.join("..", DATA_PATH))
        print(f"Created data directory: {DATA_PATH}")

    try:
        df_original = pd.read_csv(input_file_path, sep=';')
    except FileNotFoundError:
        print(f"Error: Input file not found at {input_file_path}. Please ensure it exists.")
        return
    except Exception as e:
        print(f"Error reading input CSV file: {e}")
        return

    df_original["SCORE"] = None  # Add SCORE column for semantic matching
    final_rows = []
    
    count = 0
    for group_id, group_df in df_original.groupby("ID"):
        count += 1
        if count % LONG_PAUSE_GROUPS_INTERVAL == 0 and count > 0:
            print(f"Processed {count} groups. Pausing for {LONG_PAUSE_TIME} seconds to avoid blocking...")
            time.sleep(LONG_PAUSE_TIME)

        name = group_df["NAME"].iloc[0]
        print(f"\nProcessing Group ID: {group_id}, Group Name: {name}")

        isin_code = None
        annual_url = None
        other_urls_info = []

        try:
            # Run searches
            isin_code = search_isin(name)
            annual_url = search_annual_report_url(name)
            other_urls_info = search_other_info_urls(name, KEYWORDS_DISCOVERY, VALID_YEARS, isin_code=isin_code)

            # Assign URLs depending on row TYPE
            for _, row in group_df.iterrows():
                new_row = row.copy()
                if row["TYPE"] == "FIN_REP":
                    new_row["SRC"] = annual_url if annual_url else ""
                    if annual_url:
                        # Attempt to extract year from URL first
                        year_from_url = extract_year(annual_url, VALID_YEARS)
                        if year_from_url:
                            new_row["REFYEAR"] = year_from_url
                        else: # If no year in URL, try extracting from PDF content
                            new_row["REFYEAR"] = extract_year_from_pdf_url(annual_url, VALID_YEARS, group_id=row["ID"])
                    else:
                        new_row["REFYEAR"] = ""
                    new_row["SCORE"] = ""
                else: # For other types of information
                    if other_urls_info:
                        other_url, score, year = other_urls_info.pop(0)
                        new_row["SRC"] = other_url
                        new_row["REFYEAR"] = year if year else ""
                        new_row["SCORE"] = score
                    else:
                        new_row["SRC"] = ""
                        new_row["REFYEAR"] = ""
                        new_row["SCORE"] = ""
                final_rows.append(new_row)

        except Exception as e:
            print(f"An error occurred while processing group {name} (ID: {group_id}): {e}")
            # In case of failure, append empty rows to preserve structure for this group
            for _, row in group_df.iterrows():
                new_row = row.copy()
                new_row["SRC"] = ""
                new_row["REFYEAR"] = ""
                new_row["SCORE"] = ""
                final_rows.append(new_row)

    # Final result DataFrame
    df_final_score = pd.DataFrame(final_rows)
    
    df_final = df_final_score.drop('SCORE', axis=1)

    # Save to output CSV
    try:
        df_final.to_csv(output_file_path, sep=";", index=False)
        print(f"\nProcess completed. Results saved to {output_file_path}")
    except Exception as e:
        print(f"Error saving output CSV file to {output_file_path}: {e}")

# %% [markdown]
# ### Main

# %%
if __name__ == "__main__":
    run_discovery()
# Out:
# Processing Group ID: 18490453, Group Name: ADECCO GROUP AG
#
# Processing Group ID: 18503381, Group Name: JOHNSON CONTROLS INTERNATIONAL PUBLIC LIMITED COMPANY
#
# Processing Group ID: 18503440, Group Name: MAGNA INTERNATIONAL INC
#
# Processing Group ID: 18511746, Group Name: PUBLICIS GROUPE S A
#
# Processing Group ID: 18512048, Group Name: GEBR. KNAUF
# Error getting URL https://www.bloomberg.com/profile/company/7685199Z:GR during ISIN search: 403 Client Error: Forbidden for url: https://www.bloomberg.com/profile/company/7685199Z:GR
# Error getting URL https://www.sec.gov/Archives/edgar/data/757011/000119312518188777/d594332dex991.htm during ISIN search: 403 Client Error: Forbidden for url: https://www.sec.gov/Archives/edgar/data/757011/000119312518188777/d594332dex991.htm
# Error getting URL https://www.investing.com/equities/usg-corp during ISIN search: 403 Client Error: Forbidden for url: https://www.investing.com/equities/usg-corp
#
# Processing Group ID: 18519151, Group Name: BRIDGESTONE CORPORATION
#
# Processing Group ID: 18520469, Group Name: FERRERO
# Error getting URL https://www.ferrerocareers.com/uk/en/jobs/logistics-specialist-japan during ISIN search: 404 Client Error: Not Found for url: https://www.ferrerocareers.com/uk/en/404
#
# Processing Group ID: 18521399, Group Name: SUMITOMO CORPORATION
#
# Processing Group ID: 18527213, Group Name: COMPAGNIE DE SAINT GOBAIN
#
# Processing Group ID: 18535882, Group Name: ABBOTT LABORATORIES
# Error getting URL https://www.marketwatch.com/investing/stock/abt during ISIN search: 401 Client Error: HTTP Forbidden for url: https://www.marketwatch.com/investing/stock/abt
# Error getting URL https://www.investing.com/equities/abbott-laboratories during ISIN search: 403 Client Error: Forbidden for url: https://www.investing.com/equities/abbott-laboratories
#
# Processing Group ID: 18539093, Group Name: BP P.L.C.
# Error during Google search for ISIN 'BP P.L.C.': HTTPSConnectionPool(host='www.google.com', port=443): Read timed out. (read timeout=5)
# Waiting before retrying Google search...
#
# Processing Group ID: 18541762, Group Name: ENGIE
#
# Processing Group ID: 18543139, Group Name: DENTSU GROUP INC.
# Error getting URL https://www.weforum.org/organizations/dentsu-inc/ during ISIN search: 403 Client Error: Forbidden for url: https://www.weforum.org/organizations/dentsu-inc/
# Error getting URL https://www.reuters.com/markets/companies/4324.T during ISIN search: 401 Client Error: HTTP Forbidden for url: https://www.reuters.com/markets/companies/4324.T
#
# Processing Group ID: 18552002, Group Name: THYSSENKRUPP
# Error getting URL https://es.investing.com/equities/thyssen-krupp during ISIN search: 403 Client Error: Forbidden for url: https://es.investing.com/equities/thyssen-krupp
#
# Processing Group ID: 18573648, Group Name: VOESTALPINE GROUP
#
# Processing Group ID: 18573835, Group Name: ORANGE
#
# Processing Group ID: 18581640, Group Name: ORACLE CORP
#
# Processing Group ID: 18587386, Group Name: ACCOR
# Error getting URL https://group.accor.com/en/finance/accor-share/accor-share-quotation during ISIN search: 403 Client Error: Forbidden for url: https://group.accor.com/en/finance/accor-share/accor-share-quotation
# An unexpected error occurred while processing PDF from https://docs.publicnow.com/viewDoc.aspx?filename=25108%5CEXT%5C54D05746592EC8DA81CB5314E977BC37476A2AB3_1523221F42F7847AE0CBF701E14D2C905CA244FF.PDF: 403 Client Error: Forbidden for url: https://docs.publicnow.com/viewDoc.aspx?filename=25108%5CEXT%5C54D05746592EC8DA81CB5314E977BC37476A2AB3_1523221F42F7847AE0CBF701E14D2C905CA244FF.PDF
#
# Processing Group ID: 18591402, Group Name: PROCTER & GAMBLE CO
#
# Processing Group ID: 18599238, Group Name: FCC
# Error getting URL https://www.marketwatch.com/investing/stock/fcc?countrycode=es during ISIN search: 401 Client Error: HTTP Forbidden for url: https://www.marketwatch.com/investing/stock/fcc?countrycode=es
# Error getting URL https://es.investing.com/equities/fcc during ISIN search: 403 Client Error: Forbidden for url: https://es.investing.com/equities/fcc
# Error getting URL https://www.reuters.com/markets/companies/FCC.MC during ISIN search: 401 Client Error: HTTP Forbidden for url: https://www.reuters.com/markets/companies/FCC.MC
#
# Processing Group ID: 18606822, Group Name: SOCIETE NATIONALE SNCF
#
# Processing Group ID: 18611599, Group Name: ATLAS COPCO AKTIEBOLAG
#
# Processing Group ID: 18618947, Group Name: AKTIEBOLAGET SKF
#
# Processing Group ID: 18622186, Group Name: JOHN WOOD GROUP PLC
# Error getting URL https://www.marketwatch.com/investing/stock/wdgjf during ISIN search: 401 Client Error: HTTP Forbidden for url: https://www.marketwatch.com/investing/stock/wdgjf
# Error getting URL https://www.reuters.com/markets/companies/WG.L during ISIN search: 401 Client Error: HTTP Forbidden for url: https://www.reuters.com/markets/companies/WG.L
# Error getting URL https://www.bloomberg.com/quote/WG/:LN during ISIN search: 403 Client Error: Forbidden for url: https://www.bloomberg.com/quote/WG/:LN
# Processed 25 groups. Pausing for 120 seconds to avoid blocking...
#
# Processing Group ID: 18627417, Group Name: FUJITSU LIMITED
# Error getting URL https://www.marketwatch.com/investing/stock/6702?countrycode=jp during ISIN search: 401 Client Error: HTTP Forbidden for url: https://www.marketwatch.com/investing/stock/6702?countrycode=jp
#
# Processing Group ID: 18629376, Group Name: CRH PLC
#
# Processing Group ID: 18632343, Group Name: DEUTSCHE BAHN
#
# Processing Group ID: 18636888, Group Name: CARGILL
#
# Processing Group ID: 18644473, Group Name: WARNER BROS. DISCOVERY INC.
# Error getting URL https://www.marketwatch.com/investing/stock/wbd during ISIN search: 401 Client Error: HTTP Forbidden for url: https://www.marketwatch.com/investing/stock/wbd
#
# Processing Group ID: 18646411, Group Name: GENERAL ELECTRIC COMPANY
#
# Processing Group ID: 18648074, Group Name: SAFRAN
#
# Processing Group ID: 18658675, Group Name: BASF
#
# Processing Group ID: 18665236, Group Name: APTIV PLC
# Error getting URL https://www.marketwatch.com/investing/stock/aptv during ISIN search: 401 Client Error: HTTP Forbidden for url: https://www.marketwatch.com/investing/stock/aptv
# An unexpected error occurred while processing PDF from https://www.sec.gov/Archives/edgar/data/1521332/000119312525050886/d849624dars.pdf: 403 Client Error: Forbidden for url: https://www.sec.gov/Archives/edgar/data/1521332/000119312525050886/d849624dars.pdf
#
# Processing Group ID: 18673760, Group Name: WPP PLC
#
# Processing Group ID: 18685228, Group Name: GI GROUP
# Error getting URL https://www.marketwatch.com/investing/stock/gig?countrycode=pl during ISIN search: 401 Client Error: HTTP Forbidden for url: https://www.marketwatch.com/investing/stock/gig?countrycode=pl
# Error getting URL https://www.investing.com/equities/work-service during ISIN search: 403 Client Error: Forbidden for url: https://www.investing.com/equities/work-service
# Error getting URL https://www.bloomberg.com/quote/WSE:LN during ISIN search: 403 Client Error: Forbidden for url: https://www.bloomberg.com/quote/WSE:LN
#
# Processing Group ID: 18686668, Group Name: ACCIONA
# Error getting URL https://es.investing.com/equities/acciona-sa during ISIN search: 403 Client Error: Forbidden for url: https://es.investing.com/equities/acciona-sa
#
# Processing Group ID: 18691645, Group Name: FLETCHER GROUP
#
# Processing Group ID: 18694033, Group Name: SODEXO
#
# Processing Group ID: 18700025, Group Name: ADVANCE PROPERTIES
# Error getting URL https://www.bloomberg.com/quote/ADVPSMW:AU during ISIN search: 403 Client Error: Forbidden for url: https://www.bloomberg.com/quote/ADVPSMW:AU
#
# Processing Group ID: 18705450, Group Name: AKZO NOBEL NV
#
# Processing Group ID: 18709351, Group Name: DIOR
#
# Processing Group ID: 18712196, Group Name: AMAZON
#
# Processing Group ID: 18715555, Group Name: SONY GROUP CORPORATION
# Error getting URL https://www.marketwatch.com/investing/stock/6758?countrycode=jp during ISIN search: 401 Client Error: HTTP Forbidden for url: https://www.marketwatch.com/investing/stock/6758?countrycode=jp
# An unexpected error occurred while processing PDF from https://www.sony.com/en/SonyInfo/IR/library/presen/er/pdf/24q4_sonypre.pdf: 403 Client Error: Forbidden for url: https://www.sony.com/en/SonyInfo/IR/library/presen/er/pdf/24q4_sonypre.pdf
#
# Processing Group ID: 18718848, Group Name: SONOVA
#
# Processing Group ID: 18731292, Group Name: IKEA
# incorrect startxref pointer(1)
# Processing Group ID: 18736044, Group Name: SECURITAS AB
#
# Processing Group ID: 18742207, Group Name: AIRBUS SE
#
# Processing Group ID: 18745703, Group Name: ETEX
# Error getting URL https://www.investing.com/equities/etex-sa during ISIN search: 403 Client Error: Forbidden for url: https://www.investing.com/equities/etex-sa
# An unexpected error occurred while processing PDF from https://www.etexgroup.com/en/investors/annual-reports/: EOF marker not found
#
# Processing Group ID: 18748693, Group Name: SIEMENS
# Processed 50 groups. Pausing for 120 seconds to avoid blocking...
#
# Processing Group ID: 18754669, Group Name: VODAFONE GROUP PLC
#
# Processing Group ID: 18755204, Group Name: HBIS GROUP CO. LTD.
# Error getting URL https://www.reuters.com/markets/companies/000709.SZ/ during ISIN search: 401 Client Error: HTTP Forbidden for url: https://www.reuters.com/markets/companies/000709.SZ/
# Error getting URL https://www.investing.com/equities/hebei-steel-a during ISIN search: 403 Client Error: Forbidden for url: https://www.investing.com/equities/hebei-steel-a
# Error getting URL https://www.marketwatch.com/investing/stock/000709?countrycode=cn during ISIN search: 401 Client Error: HTTP Forbidden for url: https://www.marketwatch.com/investing/stock/000709?countrycode=cn
# Error getting URL https://www.wsj.com/market-data/quotes/cn/xshe/000709 during ISIN search: 401 Client Error: HTTP Forbidden for url: https://www.wsj.com/market-data/quotes/cn/xshe/000709
# Error getting URL https://www.gurufocus.com/stock/SZSE:000709/summary during ISIN search: 403 Client Error: Forbidden for url: https://www.gurufocus.com/stock/SZSE:000709/summary
#
# Processing Group ID: 18761094, Group Name: MOL HUNGARIAN OIL AND GAS
# Error getting URL https://www.marketwatch.com/investing/stock/mol?countrycode=hu during ISIN search: 401 Client Error: HTTP Forbidden for url: https://www.marketwatch.com/investing/stock/mol?countrycode=hu
#
# Processing Group ID: 18763081, Group Name: DSV A/S
# incorrect startxref pointer(1)
# Processing Group ID: 18767600, Group Name: KRONES
#
# Processing Group ID: 18773773, Group Name: KONECRANES
#
# Processing Group ID: 18774479, Group Name: SANDVIK AKTIEBOLAG
#
# Processing Group ID: 18774712, Group Name: SKANSKA AB
# Error getting URL https://www.marketwatch.com/investing/stock/ska.b?countrycode=se during ISIN search: 401 Client Error: HTTP Forbidden for url: https://www.marketwatch.com/investing/stock/ska.b?countrycode=se
#
# Processing Group ID: 18774867, Group Name: SANOFI
#
# Processing Group ID: 18778752, Group Name: WURTH
#
# Processing Group ID: 18784770, Group Name: AKTIEBOLAGET VOLVO
#
# Processing Group ID: 18796310, Group Name: TOTALENERGIES SE
#
# Processing Group ID: 18802249, Group Name: BRITISH AMERICAN TOBACCO PLC
#
# Processing Group ID: 18803013, Group Name: NIPPON STEEL CORPORATION
# Error getting URL https://www.investing.com/equities/nippon-steel-sumitomo-metal-corp. during ISIN search: 403 Client Error: Forbidden for url: https://www.investing.com/equities/nippon-steel-sumitomo-metal-corp.
# Error getting URL https://www.marketwatch.com/investing/stock/5401?countrycode=jp during ISIN search: 401 Client Error: HTTP Forbidden for url: https://www.marketwatch.com/investing/stock/5401?countrycode=jp
#
# Processing Group ID: 18805524, Group Name: KONINKLIJKE AHOLD DELHAIZE NV
#
# Processing Group ID: 18808977, Group Name: PFIZER INC
#
# Processing Group ID: 18812865, Group Name: COCA-COLA COMPANY (THE)
#
# Processing Group ID: 18813820, Group Name: CATERPILLAR INC
#
# Processing Group ID: 18818179, Group Name: HARTMANN
# incorrect startxref pointer(1)
# Processing Group ID: 18818842, Group Name: IWG PLC
#
# Processing Group ID: 18831586, Group Name: SAP
# Error getting URL https://www.sap.com/investors/en/stock/basic-data.html during ISIN search: 403 Client Error: Forbidden for url: https://www.sap.com/investors/en/stock/basic-data.html
#
# Processing Group ID: 18839233, Group Name: ORKLA ASA
#
# Processing Group ID: 18850720, Group Name: ENEL SPA
#
# Processing Group ID: 18853782, Group Name: SHV HOLDINGS NV
# Error getting URL https://www.bloomberg.com/profile/company/SHV:NA during ISIN search: 403 Client Error: Forbidden for url: https://www.bloomberg.com/profile/company/SHV:NA
# Error getting URL https://www.marketwatch.com/investing/fund/shv/holdings during ISIN search: 401 Client Error: HTTP Forbidden for url: https://www.marketwatch.com/investing/fund/shv/holdings
#
# Processing Group ID: 18854880, Group Name: BMW
# Processed 75 groups. Pausing for 120 seconds to avoid blocking...
#
# Processing Group ID: 18858533, Group Name: THALES
# An unexpected error occurred while processing PDF from https://docs.publicnow.com/viewDoc.aspx?filename=28409%5CEXT%5C53D366E49D656A26123BFDC2EAE6154B9662E90E_91E37508D9CD4D072822628938A29BF84C96CED5.PDF: 403 Client Error: Forbidden for url: https://docs.publicnow.com/viewDoc.aspx?filename=28409%5CEXT%5C53D366E49D656A26123BFDC2EAE6154B9662E90E_91E37508D9CD4D072822628938A29BF84C96CED5.PDF
#
# Processing Group ID: 18860034, Group Name: SIGNIFY NV
#
# Processing Group ID: 18864084, Group Name: 3I GROUP PLC
#
# Processing Group ID: 18876900, Group Name: BAYER
#
# Processing Group ID: 18877286, Group Name: AKTIEBOLAGET ELECTROLUX
# Error getting URL https://www.electroluxgroup.com/en/share-price-and-trading-371/ during ISIN search: HTTPSConnectionPool(host='www.electroluxgroup.com', port=443): Read timed out. (read timeout=20)
#
# Processing Group ID: 18886469, Group Name: VEOLIA ENVIRONNEMENT
#
# Processing Group ID: 18898974, Group Name: TUI
#
# Processing Group ID: 18901386, Group Name: ASSA ABLOY AB
#
# Processing Group ID: 18908258, Group Name: RANDSTAD NV
#
# Processing Group ID: 18918108, Group Name: NV BEKAERT SA
#
# Processing Group ID: 18919705, Group Name: MANPOWERGROUP INC.
#
# Processing Group ID: 18928008, Group Name: PARAMOUNT GLOBAL
# An unexpected error occurred while processing PDF from https://www.sec.gov/Archives/edgar/data/1605607/000110465925031716/tm253273d3_ars.pdf: 403 Client Error: Forbidden for url: https://www.sec.gov/Archives/edgar/data/1605607/000110465925031716/tm253273d3_ars.pdf
#
# Processing Group ID: 18930611, Group Name: GLENCORE PLC
#
# Processing Group ID: 18931004, Group Name: DEUTSCHE LUFTHANSA
#
# Processing Group ID: 18935271, Group Name: TELEFONAKTIEBOLAGET LM ERICSSON
# Error getting URL https://www.bloomberg.com/quote/ERICB:SS during ISIN search: 403 Client Error: Forbidden for url: https://www.bloomberg.com/quote/ERICB:SS
#
# Processing Group ID: 18940840, Group Name: ABB LTD
#
# Processing Group ID: 18942704, Group Name: HP INC.
#
# Processing Group ID: 18947387, Group Name: CAPGEMINI
#
# Processing Group ID: 18953431, Group Name: MERCK GROUP
# Error getting URL https://www.marketwatch.com/investing/stock/mrk?countrycode=xe during ISIN search: 401 Client Error: HTTP Forbidden for url: https://www.marketwatch.com/investing/stock/mrk?countrycode=xe
#
# Processing Group ID: 18953450, Group Name: BPOST
#
# Processing Group ID: 18957222, Group Name: SYNLAB
# Error getting URL https://es.investing.com/equities/synlab-ag during ISIN search: 403 Client Error: Forbidden for url: https://es.investing.com/equities/synlab-ag
#
# Processing Group ID: 18959709, Group Name: L AIR LIQUIDE
#
# Processing Group ID: 18959832, Group Name: MOEVE
#
# Processing Group ID: 18967691, Group Name: GOODYEAR TIRE & RUBBER CO
#
# Processing Group ID: 18970979, Group Name: BROOKFIELD CORPORATION
# Processed 100 groups. Pausing for 120 seconds to avoid blocking...
#
# Processing Group ID: 18974095, Group Name: UMICORE
#
# Processing Group ID: 18976475, Group Name: KONE
#
# Processing Group ID: 18980415, Group Name: MICROSOFT CORPORATION
# An unexpected error occurred while processing PDF from https://www.microsoft.com/investor/reports/ar24/index.html: EOF marker not found
#
# Processing Group ID: 18981199, Group Name: GSK PLC
#
# Processing Group ID: 18984365, Group Name: NOKIA
#
# Processing Group ID: 18984744, Group Name: MONDELEZ INTERNATIONAL INC.
#
# Processing Group ID: 18986164, Group Name: TELEFONICA
# Error getting URL https://es.investing.com/equities/telefonica during ISIN search: 403 Client Error: Forbidden for url: https://es.investing.com/equities/telefonica
#
# Processing Group ID: 18987927, Group Name: ENI S P A
#
# Processing Group ID: 18988574, Group Name: ARCELORMITTAL
#
# Processing Group ID: 18990015, Group Name: HEIDELBERGCEMENT
# Error getting URL https://www.investing.com/equities/heidelbergcement-ag-exch during ISIN search: 403 Client Error: Forbidden for url: https://www.investing.com/equities/heidelbergcement-ag-exch
#
# Processing Group ID: 18990928, Group Name: INTERNATIONAL BUSINESS MACHINES CORP(IBM)
# An unexpected error occurred while processing PDF from https://www.ibm.com/investor/services/annual-report: EOF marker not found
#
# Processing Group ID: 18997891, Group Name: MEDTRONIC PLC
# Error getting URL https://www.marketwatch.com/investing/stock/mdt during ISIN search: 401 Client Error: HTTP Forbidden for url: https://www.marketwatch.com/investing/stock/mdt
#
# Processing Group ID: 19004631, Group Name: NESTLE S.A.
#
# Processing Group ID: 19011564, Group Name: SODIM
# Error getting URL /search?num=12 during ISIN search: Invalid URL '/search?num=12': No scheme supplied. Perhaps you meant https:///search?num=12?
#
# Processing Group ID: 19013259, Group Name: META PLATFORMS INC.
#
# Processing Group ID: 19017221, Group Name: NOVOMATIC GROUP
#
# Processing Group ID: 19019578, Group Name: HUSQVARNA AB
#
# Processing Group ID: 19031780, Group Name: WALT DISNEY COMPANY (THE)
#
# Processing Group ID: 19032544, Group Name: RETHMANN
# Error getting URL https://www.bloomberg.com/profile/company/383116Z:GR during ISIN search: 403 Client Error: Forbidden for url: https://www.bloomberg.com/profile/company/383116Z:GR
#
# Processing Group ID: 19032847, Group Name: MITSUI & CO LTD
#
# Processing Group ID: 19037620, Group Name: JBS S.A.
#
# Processing Group ID: 19037648, Group Name: H & M HENNES & MAURITZ
#
# Processing Group ID: 19041196, Group Name: MERCEDES-BENZ GROUP
#
# Processing Group ID: 19041914, Group Name: PEPSICO INC
#
# Processing Group ID: 19042061, Group Name: COMPASS GROUP PLC
# Processed 125 groups. Pausing for 120 seconds to avoid blocking...
#
# Processing Group ID: 19044103, Group Name: ATOS SE
#
# Processing Group ID: 19044732, Group Name: VOLKSWAGEN
#
# Processing Group ID: 19045186, Group Name: TOYOTA MOTOR CORPORATION
#
# Processing Group ID: 19050011, Group Name: DEUTSCHE TELEKOM
#
# Processing Group ID: 19050406, Group Name: ITOCHU CORPORATION
#
# Processing Group ID: 19052995, Group Name: ALSTOM
#
# Processing Group ID: 19053695, Group Name: DANONE
#
# Processing Group ID: 19057037, Group Name: THERMO FISHER SCIENTIFIC INC.
#
# Processing Group ID: 19060705, Group Name: NIPPON TELEGRAPH AND TELEPHONE CORPORATION
#
# Processing Group ID: 19061929, Group Name: ZHEJIANG GEELY HOLDING GROUP CO LTD
# Error getting URL https://www.bloomberg.com/profile/company/GEELZ:CH during ISIN search: 403 Client Error: Forbidden for url: https://www.bloomberg.com/profile/company/GEELZ:CH
# Error getting URL https://www.investing.com/equities/geely-automobile-holdings-ownership during ISIN search: 403 Client Error: Forbidden for url: https://www.investing.com/equities/geely-automobile-holdings-ownership
#
# Processing Group ID: 19063169, Group Name: DEUTSCHE POST
#
# Processing Group ID: 19063238, Group Name: ACCENTURE PLC
# Error getting URL https://www.marketwatch.com/investing/stock/acn during ISIN search: 401 Client Error: HTTP Forbidden for url: https://www.marketwatch.com/investing/stock/acn
#
# Processing Group ID: 19071003, Group Name: SCHAEFFLER
#
# Processing Group ID: 19078026, Group Name: SINOCHEM
# Error getting URL https://www.investing.com/equities/sinochem during ISIN search: 403 Client Error: Forbidden for url: https://www.investing.com/equities/sinochem
# Error getting URL https://www.reuters.com/markets/companies/600500.SS during ISIN search: 401 Client Error: HTTP Forbidden for url: https://www.reuters.com/markets/companies/600500.SS
# Error getting URL https://www.wsj.com/market-data/quotes/cn/xshg/600500 during ISIN search: 401 Client Error: HTTP Forbidden for url: https://www.wsj.com/market-data/quotes/cn/xshg/600500
# Error getting URL https://www.bloomberg.com/quote/600500:CH during ISIN search: 403 Client Error: Forbidden for url: https://www.bloomberg.com/quote/600500:CH
#
# Processing Group ID: 19078254, Group Name: BOUYGUES
# An unexpected error occurred while processing PDF from https://www.bouygues.com/wp-content/uploads/docs/91140/financial-statements-for-bouygues-and-its-subsidiaries.pdf: 403 Client Error: Forbidden for url: https://www.bouygues.com/wp-content/uploads/docs/91140/financial-statements-for-bouygues-and-its-subsidiaries.pdf
#
# Processing Group ID: 19081380, Group Name: EDP
#
# Processing Group ID: 19089102, Group Name: NOVARTIS AG
#
# Processing Group ID: 19098069, Group Name: EXXON MOBIL CORP
#
# Processing Group ID: 19098782, Group Name: HENKEL KGAA
#
# Processing Group ID: 19103593, Group Name: D IETEREN GROUP
#
# Processing Group ID: 19106201, Group Name: HEINEKEN
#
# Processing Group ID: 19112336, Group Name: INDITEX
#
# Processing Group ID: 19118622, Group Name: IBERDROLA
#
# Processing Group ID: 19143810, Group Name: JOHN SWIRE & SONS LIMITED
#
# Processing Group ID: 19145378, Group Name: ESSITY
# Error getting URL https://www.marketwatch.com/investing/stock/essity.a?countrycode=se during ISIN search: 401 Client Error: HTTP Forbidden for url: https://www.marketwatch.com/investing/stock/essity.a?countrycode=se
# Processed 150 groups. Pausing for 120 seconds to avoid blocking...
#
# Processing Group ID: 19149741, Group Name: LEONARDO SOCIETA PER AZIONI
# Error during Google search for other info 'LEONARDO SOCIETA PER AZIONI': HTTPSConnectionPool(host='www.google.com', port=443): Read timed out.
# Waiting before retrying Google search...
#
# Processing Group ID: 19157606, Group Name: BOSCH
#
# Processing Group ID: 19159067, Group Name: DELL TECHNOLOGIES INC.
# Error getting URL https://www.marketwatch.com/investing/stock/dell during ISIN search: 401 Client Error: HTTP Forbidden for url: https://www.marketwatch.com/investing/stock/dell
# An unexpected error occurred while processing PDF from https://i.dell.com/sites/csdocuments/App-Merchandizing_Documents/en/ie/Dell_Bank_International_Financial_Statements_31.01.2025_Signed.pdf: 403 Client Error: Forbidden for url: https://i.dell.com/sites/csdocuments/App-Merchandizing_Documents/en/ie/Dell_Bank_International_Financial_Statements_31.01.2025_Signed.pdf
#
# Processing Group ID: 19159307, Group Name: INTERTEK GROUP PLC
#
# Processing Group ID: 19174661, Group Name: ESSILORLUXOTTICA
#
# Processing Group ID: 19187838, Group Name: ALPHABET INC.
#
# Processing Group ID: 19191179, Group Name: MARUBENI CORPORATION
#
# Processing Group ID: 19191444, Group Name: RELX PLC
#
# Processing Group ID: 19191498, Group Name: BOLLORE PARTICIPATIONS SE
#
# Processing Group ID: 19192598, Group Name: JOHNSON & JOHNSON
#
# Processing Group ID: 19196807, Group Name: CARREFOUR
#
# Processing Group ID: 19201457, Group Name: ALFA LAVAL AB
# Error getting URL https://www.marketwatch.com/investing/stock/alfa?countrycode=se during ISIN search: 401 Client Error: HTTP Forbidden for url: https://www.marketwatch.com/investing/stock/alfa?countrycode=se
#
# Processing Group ID: 19206259, Group Name: SGS
# Error getting URL https://www.investing.com/equities/sgs during ISIN search: 403 Client Error: Forbidden for url: https://www.investing.com/equities/sgs
# Error getting URL https://es.investing.com/equities/sgs during ISIN search: 403 Client Error: Forbidden for url: https://es.investing.com/equities/sgs
# Error getting URL https://www.bloomberg.com/quote/SGSN:SW during ISIN search: 403 Client Error: Forbidden for url: https://www.bloomberg.com/quote/SGSN:SW
#
# Processing Group ID: 19216371, Group Name: COMPAGNIE GENERALE DES ETABLISSEMENTS MICHELIN
#
# Processing Group ID: 19217026, Group Name: HITACHI LTD
#
# Processing Group ID: 19226059, Group Name: HOLCIM AG
#
# Processing Group ID: 19231130, Group Name: SCHNEIDER ELECTRIC SE
#
# Processing Group ID: 19233882, Group Name: EUROFINS SCIENTIFIC
#
# Processing Group ID: 19234151, Group Name: REPSOL
#
# Processing Group ID: 19238855, Group Name: ANHEUSER-BUSCH INBEV
# An unexpected error occurred while processing PDF from https://docs.publicnow.com/viewDoc.aspx?filename=21442%5CEXT%5CF5FD893680B274CEB2112185B4A2FEAEDC89F864_0D37C659B38D43A54F0C6FF2CA87CC484589A406.PDF: 403 Client Error: Forbidden for url: https://docs.publicnow.com/viewDoc.aspx?filename=21442%5CEXT%5CF5FD893680B274CEB2112185B4A2FEAEDC89F864_0D37C659B38D43A54F0C6FF2CA87CC484589A406.PDF
#
# Processing Group ID: 19245907, Group Name: SAMSUNG ELECTRONICS CO. LTD.
# Error getting URL https://www.investing.com/equities/samsung-electronics-co-ltd during ISIN search: 403 Client Error: Forbidden for url: https://www.investing.com/equities/samsung-electronics-co-ltd
# Error getting URL https://www.bloomberg.com/quote/005930:KS during ISIN search: 403 Client Error: Forbidden for url: https://www.bloomberg.com/quote/005930:KS
#
# Processing Group ID: 19249932, Group Name: NOVO NORDISK
# Error getting URL https://www.investing.com/equities/novo-nordis during ISIN search: 403 Client Error: Forbidden for url: https://www.investing.com/equities/novo-nordis
#
# Processing Group ID: 19253725, Group Name: SOLVAY
#
# Processing Group ID: 19258448, Group Name: BERTELSMANN STIFTUNG
# Error getting URL https://www.marketwatch.com/investing/stock/btg?countrycode=de&iso=xfra during ISIN search: 401 Client Error: HTTP Forbidden for url: https://www.marketwatch.com/investing/stock/btg?countrycode=de&iso=xfra
#
# Processing Group ID: 19261077, Group Name: ASTRAZENECA PLC
# Error getting URL http://tools.morningstar.es/es/stockreport/default.aspx?SecurityToken=0P00007NYP]3]0]E0WWE$$ALL during ISIN search: HTTPConnectionPool(host='tools.morningstar.es', port=80): Read timed out. (read timeout=20)
# Processed 175 groups. Pausing for 120 seconds to avoid blocking...
#
# Processing Group ID: 19264134, Group Name: ISS A/S
# Error getting URL https://www.investing.com/equities/iss-a-s during ISIN search: 403 Client Error: Forbidden for url: https://www.investing.com/equities/iss-a-s
# Error getting URL https://www.reuters.com/markets/companies/ISS.CO during ISIN search: 401 Client Error: HTTP Forbidden for url: https://www.reuters.com/markets/companies/ISS.CO
# Error getting URL https://www.bloomberg.com/quote/ISS:DC during ISIN search: 403 Client Error: Forbidden for url: https://www.bloomberg.com/quote/ISS:DC
# Error getting URL https://www.marketwatch.com/investing/stock/iss?countrycode=dk during ISIN search: 401 Client Error: HTTP Forbidden for url: https://www.marketwatch.com/investing/stock/iss?countrycode=dk
# incorrect startxref pointer(1)
# An unexpected error occurred while processing PDF from https://regnskaber.cvrapi.dk/xhtml/59380412/amNsb3VkczovLzAzL2I5LzI3LzVkL2M2L2RlNTgtNDNjNS1hMjY3LWZhZDIyMGY2YjlkYw.pdf: xref table read error
#
# Processing Group ID: 19266518, Group Name: WIENERBERGER GROUP
# Error getting URL https://www.investing.com/equities/wienerberger during ISIN search: 403 Client Error: Forbidden for url: https://www.investing.com/equities/wienerberger
#
# Processing Group ID: 19275814, Group Name: VESTAS WIND SYSTEMS A/S
# Error getting URL https://www.investing.com/equities/vestas-wind during ISIN search: 403 Client Error: Forbidden for url: https://www.investing.com/equities/vestas-wind
#
# Processing Group ID: 19276100, Group Name: YARA INTERNATIONAL ASA
#
# Processing Group ID: 19286023, Group Name: MITSUBISHI CORPORATION
#
# Processing Group ID: 19287986, Group Name: ZF FRIEDRICHSHAFEN
#
# Processing Group ID: 19297963, Group Name: KRKA TOVARNA ZDRAVIL DD NOVO MESTO
# Error getting URL https://www.gpw.pl/company-factsheet?isin=SI0031102120 during ISIN search: ('Connection aborted.', RemoteDisconnected('Remote end closed connection without response'))
# Error getting URL https://webapi.krka.biz/en/for-investors/shareholder-information/share-information/ during ISIN search: HTTPSConnectionPool(host='webapi.krka.biz', port=443): Max retries exceeded with url: /en/for-investors/shareholder-information/share-information/ (Caused by SSLError(SSLEOFError(8, '[SSL: UNEXPECTED_EOF_WHILE_READING] EOF occurred in violation of protocol (_ssl.c:1010)')))
#
# Processing Group ID: 19300811, Group Name: PRYSMIAN S.P.A.
#
# Processing Group ID: 19312144, Group Name: CANON INCORPORATED
#
# Processing Group ID: 19313683, Group Name: STANLEY BLACK & DECKER INC.
#
# Processing Group ID: 19314055, Group Name: NORSK HYDRO ASA
#
# Processing Group ID: 19331837, Group Name: EDIZIONE
# Error getting URL https://www.bloomberg.com/profile/company/3284233Z:IM during ISIN search: 403 Client Error: Forbidden for url: https://www.bloomberg.com/profile/company/3284233Z:IM
#
# Processing Group ID: 19340550, Group Name: VINCI
#
# Processing Group ID: 19344352, Group Name: KUEHNE NAGEL
#
# Processing Group ID: 19346455, Group Name: STRABAG GROUP
#
# Processing Group ID: 19414796, Group Name: ATLAS UK BIDCO LIMITED
#
# Processing Group ID: 20016646, Group Name: UNILEVER PLC
#
# Processing Group ID: 20029695, Group Name: PROSEGUR
# Error getting URL https://www.marketwatch.com/investing/stock/psg?countrycode=es during ISIN search: 401 Client Error: HTTP Forbidden for url: https://www.marketwatch.com/investing/stock/psg?countrycode=es
# Error getting URL https://es.investing.com/equities/prosegur-sa during ISIN search: 403 Client Error: Forbidden for url: https://es.investing.com/equities/prosegur-sa
# Error getting URL https://www.investing.com/equities/prosegur-sa during ISIN search: 403 Client Error: Forbidden for url: https://www.investing.com/equities/prosegur-sa
#
# Processing Group ID: 20083504, Group Name: EATON CORPORATION PLC
#
# Processing Group ID: 20321242, Group Name: ANDRITZ GROUP
#
# Processing Group ID: 20336161, Group Name: ASSECO
# Error getting URL https://www.marketwatch.com/investing/stock/acp?countrycode=pl during ISIN search: 401 Client Error: HTTP Forbidden for url: https://www.marketwatch.com/investing/stock/acp?countrycode=pl
#
# Processing Group ID: 20344223, Group Name: ELECTRICITE DE FRANCE
# Error getting URL https://www.investing.com/equities/edf during ISIN search: 403 Client Error: Forbidden for url: https://www.investing.com/equities/edf
#
# Processing Group ID: 20345723, Group Name: A.P. MOLLER - MAERSK
#
# Processing Group ID: 20397226, Group Name: L OREAL
#
# Processing Group ID: 20449369, Group Name: CARLSBERG A/S
# Processed 200 groups. Pausing for 120 seconds to avoid blocking...
#
# Processing Group ID: 20530530, Group Name: STELLANTIS
#
# Process completed. Results saved to ..\data\discovery_complete.csv
